# %%
# !pip install syft
# Out:
# ...
#   Using cached syft-0.6.0-py2.py3-none-any.whl (606 kB)
# ...
#   Using cached ascii_magic-1.6-py3-none-any.whl (7.6 kB)
# ...
#   Using cached packaging-21.2-py3-none-any.whl (40 kB)
# ...
#      |████████████████████████████████| 11.3 MB 4.5 MB/s eta 0:00:01
# ...
#   Using cached sympy-1.9-py3-none-any.whl (6.2 MB)
# ...
#      |████████████████████████████████| 1.6 MB 66.3 MB/s eta 0:00:01
# ...
#   Using cached pymbolic-2021.1.tar.gz (84 kB)
# ...
#   Using cached importlib_metadata-4.8.2-py3-none-any.whl (17 kB)
# ...
#   Using cached typing_extensions-4.0.0-py3-none-any.whl (22 kB)
# ...
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/eb/59/ada45144bea5fb8b6abaff2195237721beae20a0f129722f493d91403469/torch-1.10.0-cp39-cp39-manylinux1_x86_64.whl
# ...

# %%
import syft
